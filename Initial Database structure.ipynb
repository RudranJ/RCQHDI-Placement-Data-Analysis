# %%
import pandas as pd

file_path = 'Trial Data 1-23.csv' 


df = pd.read_csv(file_path, encoding='latin1')

print("DataFrame Info:")
df.info()

print("\nFirst 5 rows of the DataFrame:")
print(df.head())

print("\nAll Column Names:")
for column in df.columns:
    print(column)

columns_to_check_unique = [
    'Sex', 'Age', 'Region', 'HIV Status',
    'Last result of HCS (AntiHCV)', 'Last result of HBV test (HBsAg)',
    'ART Started', 'Route of transmission', 'Outcome of HCV treatment',
    'CD4 Initial', 'CD4 Latest', 'Viral Load Latest',
    'Date of Birth', 'Treatment Start Date', 'Treatment End Date',
    'Since when has been using drugs', 'Alcohol abuse', 'Migrant',
    'D-examination:Injecting drug use in the last 6 months',
    'D-examination:Sexual contacts in the last 6 months',
    'D-examination:Provision of commercial sex services in the last 6 months'
]

print("\n--- Key Column Insights (Unique Values) ---")
for col in columns_to_check_unique:
    if col in df.columns:
        print(f"\nUnique values in '{col}':")
        print([str(val) for val in df[col].unique()])
    else:
        print(f"\nColumn '{col}' not found in the DataFrame.")

print("\nDescriptive statistics for numerical columns:")
print(df.describe())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Columns: 171 entries, Country of arrival (for foreigners) to NGO: Date of service provision
# dtypes: float64(35), int64(1), object(135)
# memory usage: 65.6+ KB
#
# First 5 rows of the DataFrame:
#   Country of arrival (for foreigners) Current area of medical examination  \
# 0                                 NaN                              BATKEN
# 1                                 NaN                              BATKEN
# 2                                 NaN                              BATKEN
# 3                                 NaN                              BATKEN
# 4                                 NaN                              BATKEN
#
#      Citizenship Date of IB/PCR/ELISA Sex  Age  \
# 0  Citizen of KR           2025-06-13   ?   38
# 1  Citizen of KR           2025-06-04   ?   23
# 2  Citizen of KR           2025-04-30   ?   58
# 3  Citizen of KR           2025-03-28   ?   19
# 4  Citizen of KR           2025-03-28   ?   43
#
#    ????????? ????????? ?? (?????/??)         On D-account in  \
# 0                            340000.0  Batken OC HGV and HIV
# 1                            362000.0           CSM Kadamjay
# 2                            348000.0  Batken OC HGV and HIV
# 3                            509000.0         CSM Kyzyl-Kyya
# 4                             60400.0             CSM Leilek
#
#   Date of ART initiation Date of D-registration  ...  \
# 0             2025-06-16             2025-06-16  ...
# 1             2025-06-05             2025-06-05  ...
# 2             2025-05-13             2025-05-13  ...
# 3             2025-04-07             2025-04-07  ...
# 4             2025-04-02             2025-04-02  ...
#
#   To whom the drug was dispensed Sexual contacts (homo) ever  \
# 0                 To the patient                         Yes
# 1                 To the patient                          No
# 2                 To the patient                         NaN
# 3                 To the patient                         NaN
# 4                 To the patient                         NaN
#
#   RS: Have you ever had experience of providing commercial sex services  \
# 0                                                NaN
# 1                                                 No
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   RR: PLHIV informed RR: Date of information  \
# 0                NaN                     NaN
# 1                Yes              2025-06-05
# 2                Yes              2025-05-12
# 3                Yes              2025-04-07
# 4                NaN                     NaN
#
#   ??: ???????? ?? ????????? ????? ??????? ??????????  RR: Date of consent  \
# 0                                                NaN                  NaN
# 1                                                Yes           2025-06-05
# 2                                                Yes           2025-05-13
# 3                                                Yes           2025-04-07
# 4                                                NaN                  NaN
#
#   RR: Date of the first contact with a peer navigator  \
# 0                                                NaN
# 1                                         2025-06-05
# 2                                         2025-05-12
# 3                                         2025-04-07
# 4                                                NaN
#
#   NGO: Name of the organization that provided the service  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   NGO: Date of service provision
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 171 columns]
#
# All Column Names:
# Country of arrival (for foreigners)
# Current area of medical examination
# Citizenship
# Date of IB/PCR/ELISA
# Sex
# Age
# ????????? ????????? ?? (?????/??)
# On D-account in
# Date of ART initiation
# Date of D-registration
# Detected in KR
# Country of detection
# Region of detection
# Administrative unit of detection
# UIC
# Last result of HCS (AntiHCV)
# Last result of HBV test (HBsAg)
# HBV vaccination
# Date of initiation of HCV treatment
# Examination code
# Date of birth
# Transgender
# IB/PCR/ELISA number
# IB conclusion
# Route of transmission
# Retrospective child
# LUIN
# Since when has been using drugs
# Registered with a narcologist
# Alcohol abuse
# Full name of the attending physician
# Registration address: region
# Registration address: administrative unit of the region
# Registration address: locality
# Registration address (c/v)
# Residential address: region
# Residential address: administrative unit of the region
# Residential address: locality
# Residential address: street, house, apartment
# Residential address (c/v)
# Attached polyclinic
# Place of residence (c/v) at the time of detection
# Migrant
# Date of entry
# Date of exit
# Country of migration
# Date of initial D-registration
# Ambulatory card No.
# Penitentiary institution (currently located)
# Date of diagnosis
# Diagnosis
# AIDS-indicator diseases
# AIDS-indicator diseases ICD-10
# Date of the first CD4 result
# ?????? ????????? CD4 (??/??)
# Date of the first CD4 result <= 500
# First CD4 result (cells/ml) <= 500
# Date of the first CD4 result <= 350
# First CD4 result (cells/ml) <= 350
# Date of the penultimate CD4 result
# ????????????? ????????? CD4 (??/??)
# Date of the last CD4 result
# ????????? ????????? CD4 (??/??)
# Last result of %CD4
# Date of the first VL result
# First VL result (copies/ml)
# Date of the penultimate VL result
# ????????????? ????????? ?? (?????/??)
# Date of the last material collection for VL
# Date of the last VL result
# Reason for high VL
# Last VL note
# ???? ???????????? ????????? ??? ???
# ???? ???????????? ?????????? ? ?????? ???
# Obtaining written consent for ART
# Date of primary ART initiation
# Date of initiation of the current course of ART
# Row
# Previous treatment regimen
# Regimen
# Drug
# ART is provided by
# ????????? ?????????????? ??? ????????
# ????. ?????? ??????????????
# ???? ????. ?????? ??????????????
# Reasons for low adherence
# Toxic reactions / side effects
# Last date of change in ART
# Type of the last change in ART
# Reason for the last change in ART
# Last date of HBV(HBsAg) registration
# Date of the last HCS result (AntiHCV)
# Liver cirrhosis
# HCV treatment regimen
# Date of completion of HCV treatment
# Outcome of HCV treatment
# Reason for the outcome of HCV treatment
# Date of the last fluorography
# ????. ????????? ????????????
# Date of the last radiography
# ????. ????????? ??????????????
# Date of the last Xpert MTB
# Last result of Xpert MTB
# Date of the last phthisiatrician's consultation
# Result of the last phthisiatrician's consultation
# Last sputum smear microscopy
# Date of the last sputum smear microscopy
# ???? ?????????? ????. ?????? ??
# Patient type (case)
# TB diagnosis according to ICD-10
# Localization
# Bacilli excretion
# Date of treatment initiation
# Date of treatment completion
# Outcome
# ??????? ?? ? ????????
# Date of survey for TB symptoms
# Result of survey for TB symptoms
# Date of LAM test
# Result of LAM test
# Date of registration at the TB dispensary
# Pregnant
# Date of establishing indications for co-trimoxazole
# ??-???????????: ???? ??????
# Co-trimoxazole: end date
# Date of establishing indications for isoniazid
# Isoniazid: start date
# Isoniazid: end date
# Date of establishing indications for fluconazole
# Fluconazole: start date
# Fluconazole: end date
# Date of establishing indications for Azithromycin/Clarithromycin
# Azithromycin/Clarithromycin: start date
# Azithromycin/Clarithromycin: end date
# Last date of OST registration
# Name of the organization providing OST
# Last date of OST dispensing
#  ?? ????? ?????????? ???? ???? ??????
# Date of OST withdrawal
# Last reason for OST withdrawal
# Date of D-examination
# Planned date of D-examination
# D-examination:Injecting drug use in the last 6 months
# D-examination:Referral to a substitution therapy program
# D-examination:Sexual contacts in the last 6 months
# D-examination:Provision of commercial sex services in the last 6 months
# Reason for not being tested for VL
# D-examination:Reason for not starting ART
# Inpatient treatment
# Outpatient treatment
# Last area of medical examination
# Last organization of D-registration
# Last date of D-registration withdrawal
# Reason for D-registration withdrawal
# Region of registration
# Administrative territory of registration
# CSPID of registration
# Start of social assistance
# End of social assistance
# Date of ARV drug dispensing
# Scheduled date of ARV drug dispensing
# To whom the drug was dispensed
# Sexual contacts (homo) ever
# RS: Have you ever had experience of providing commercial sex services
# RR: PLHIV informed
# RR: Date of information
# ??: ???????? ?? ????????? ????? ??????? ??????????
# RR: Date of consent
# RR: Date of the first contact with a peer navigator
# NGO: Name of the organization that provided the service
# NGO: Date of service provision
#
# --- Key Column Insights (Unique Values) ---
#
# Unique values in 'Sex':
# ['?']
#
# Unique values in 'Age':
# ['38', '23', '58', '19', '43', '32', '29', '44', '30', '35', '26', '36', '2', '37', '46', '18', '50', '15', '33', '65', '7', '1', '41', '57', '56', '51', '31', '24', '45', '52', '34', '22', '39', '25']
#
# Column 'Region' not found in the DataFrame.
#
# Column 'HIV Status' not found in the DataFrame.
#
# Unique values in 'Last result of HCS (AntiHCV)':
# ['Negative', 'nan', 'Positive']
#
# Unique values in 'Last result of HBV test (HBsAg)':
# ['Negative', 'nan', 'Positive']
#
# Column 'ART Started' not found in the DataFrame.
#
# Unique values in 'Route of transmission':
# ['Homosexual, sexual', 'Heterosexual, sexual', 'Undetermined route', '???????????? (?? ????? ????????????, ?????, ??? ????????? ??????)']
#
# Unique values in 'Outcome of HCV treatment':
# ['nan', '??? 12']
#
# Column 'CD4 Initial' not found in the DataFrame.
#
# Column 'CD4 Latest' not found in the DataFrame.
#
# Column 'Viral Load Latest' not found in the DataFrame.
#
# Column 'Date of Birth' not found in the DataFrame.
#
# Column 'Treatment Start Date' not found in the DataFrame.
#
# Column 'Treatment End Date' not found in the DataFrame.
#
# Unique values in 'Since when has been using drugs':
# ['nan']
#
# Unique values in 'Alcohol abuse':
# ['No', 'nan']
#
# Unique values in 'Migrant':
# ['No']
#
# Unique values in 'D-examination:Injecting drug use in the last 6 months':
# ['No', 'No ??????']
#
# Unique values in 'D-examination:Sexual contacts in the last 6 months':
# ['No contacts', 'No ??????', 'Only with men', '?????? ? ?????????', '? ? ?????????, ? ? ?????????']
#
# Unique values in 'D-examination:Provision of commercial sex services in the last 6 months':
# ['No', 'No ??????']
#
# Descriptive statistics for numerical columns:
#              Age  ????????? ????????? ?? (?????/??)   Transgender  \
# count  49.000000                           49.000000          0.0
# mean   34.938776                        37229.970612          NaN
# std    13.955895                       111406.729262          NaN
# min     1.000000                            1.000000          NaN
# 25%    26.000000                           40.000000          NaN
# 50%    34.000000                           40.000000          NaN
# 75%    44.000000                          114.000000          NaN
# max    65.000000                       509000.000000          NaN
#
#        Since when has been using drugs  \
# count                              0.0
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#        Penitentiary institution (currently located)  \
# count                                           0.0
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        ?????? ????????? CD4 (??/??)   First CD4 result (cells/ml) <= 500  \
# count                      35.000000                           35.000000
# mean                      392.828571                          509.714286
# std                       397.940395                          383.884371
# min                         0.000000                           72.000000
# 25%                       201.500000                          313.000000
# 50%                       377.000000                          435.000000
# 75%                       429.500000                          639.000000
# max                      2418.000000                         2340.000000
#
#        First CD4 result (cells/ml) <= 350  \
# count                           17.000000
# mean                           181.000000
# std                            110.898602
# min                              0.000000
# 25%                            110.000000
# 50%                            189.000000
# 75%                            268.000000
# max                            346.000000
#
#        ????????????? ????????? CD4 (??/??)   ????????? ????????? CD4 (??/??)   \
# count                             29.000000                         35.000000
# mean                             420.689655                        509.714286
# std                              426.462116                        383.884371
# min                                0.000000                         72.000000
# 25%                              244.000000                        313.000000
# 50%                              387.000000                        435.000000
# 75%                              476.000000                        639.000000
# max                             2418.000000                       2340.000000
#
#        ...  Date of OST withdrawal  Last reason for OST withdrawal  \
# count  ...                     0.0                             0.0
# mean   ...                     NaN                             NaN
# std    ...                     NaN                             NaN
# min    ...                     NaN                             NaN
# 25%    ...                     NaN                             NaN
# 50%    ...                     NaN                             NaN
# 75%    ...                     NaN                             NaN
# max    ...                     NaN                             NaN
#
#        Reason for not being tested for VL  \
# count                                 0.0
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#        D-examination:Reason for not starting ART  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        Last date of D-registration withdrawal  \
# count                                     0.0
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#        Reason for D-registration withdrawal  Start of social assistance  \
# count                                   0.0                         0.0
# mean                                    NaN                         NaN
# std                                     NaN                         NaN
# min                                     NaN                         NaN
# 25%                                     NaN                         NaN
# 50%                                     NaN                         NaN
# 75%                                     NaN                         NaN
# max                                     NaN                         NaN
#
#        End of social assistance  \
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#        NGO: Name of the organization that provided the service  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        NGO: Date of service provision
# count                             0.0
# mean                              NaN
# std                               NaN
# min                               NaN
# 25%                               NaN
# 50%                               NaN
# 75%                               NaN
# max                               NaN
#
# [8 rows x 36 columns]
